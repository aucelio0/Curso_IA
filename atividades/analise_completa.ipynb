# %% [markdown]
# ## Análise do dataset dos candidatos

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# importa a variavel de outro notebook

# %%
# %store -r df_total

# %%
df_total
# Out:
#       id_candidato       sexo estado  idade      formacao      area_atuacao  \
# 0                1  Masculino     SP   23.0      Mestrado        Financeiro
# 1                2  Masculino     MG    NaN  Ensino Médio     Administração
# 2                3  Masculino     DF   61.0     Doutorado     Administração
# 3                4      Outro     PE   28.0           NaN        Engenharia
# 4                5      Outro     RS   19.0  Ensino Médio        Tecnologia
# ...            ...        ...    ...    ...           ...               ...
# 2995           996  Masculino     MG   60.0      Mestrado  Recursos Humanos
# 2996           997        NaN     CE   56.0     Doutorado        Engenharia
# 2997           998        NaN     RS   34.0     Doutorado         Marketing
# 2998           999   Feminino     PR   37.0  Ensino Médio        Tecnologia
# 2999          1000  Masculino     RJ   41.0  Ensino Médio        Tecnologia
#
# ...

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id_candidato        3000 non-null   int64
#  1   sexo                2700 non-null   object
#  2   estado              2700 non-null   object
#  3   idade               2700 non-null   float64
#  4   formacao            2700 non-null   object
#  5   area_atuacao        2700 non-null   object
#  6   tempo_experiencia   2700 non-null   float64
#  7   certificacoes       2700 non-null   float64
#  8   idiomas             2700 non-null   object
#  9   pretensao_salarial  2700 non-null   float64
#  10  salario             2700 non-null   float64
#  11  aceita_viagem       2700 non-null   object
#  12  aceita_mudanca      2700 non-null   object
#  13  pcd                 2700 non-null   object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 328.3+ KB

# %% [markdown]
# ### Analisando qual melhor cadidato para contratação
